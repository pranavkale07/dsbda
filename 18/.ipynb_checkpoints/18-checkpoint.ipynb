# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
df=pd.read_csv('heart.csv')

display(df)
df.columns
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# a. Histogram

plt.figure(figsize=(10,4))
plt.hist(df['age'],bins=10,edgecolor='black')
plt.title('Age vs Count')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# b. Pie Chart

counts=df['age'].value_counts()
plt.pie(counts,labels=counts.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x2377d52d000>,
#   <matplotlib.patches.Wedge at 0x2377d52cf10>,
#   <matplotlib.patches.Wedge at 0x2377d52d810>,
#   <matplotlib.patches.Wedge at 0x2377d52dc90>,
#   <matplotlib.patches.Wedge at 0x2377d52e110>,
#   <matplotlib.patches.Wedge at 0x2377d52e590>,
#   <matplotlib.patches.Wedge at 0x2377d52ea10>,
#   <matplotlib.patches.Wedge at 0x2377d52ee90>,
#   <matplotlib.patches.Wedge at 0x2377d52f310>,
#   <matplotlib.patches.Wedge at 0x2377d52f790>,
#   <matplotlib.patches.Wedge at 0x2377d52cfd0>,
#   <matplotlib.patches.Wedge at 0x2377d56c0a0>,
#   <matplotlib.patches.Wedge at 0x2377d56c520>,
#   <matplotlib.patches.Wedge at 0x2377d56c9a0>,
#   <matplotlib.patches.Wedge at 0x2377d56ce20>,
#   <matplotlib.patches.Wedge at 0x2377d56d2a0>,
#   <matplotlib.patches.Wedge at 0x2377d56d720>,
#   <matplotlib.patches.Wedge at 0x2377d56dba0>,
#   <matplotlib.patches.Wedge at 0x2377d56e020>,
#   <matplotlib.patches.Wedge at 0x2377d56e4a0>,
#   <matplotlib.patches.Wedge at 0x2377d56e920>,
#   <matplotlib.patches.Wedge at 0x2377d56eda0>,
#   <matplotlib.patches.Wedge at 0x2377d46f070>,
#   <matplotlib.patches.Wedge at 0x2377d56f370>,
#   <matplotlib.patches.Wedge at 0x2377d56f7f0>,
#   <matplotlib.patches.Wedge at 0x2377d56fc70>,
#   <matplotlib.patches.Wedge at 0x2377d5ac130>,
#   <matplotlib.patches.Wedge at 0x2377d5ac5b0>,
#   <matplotlib.patches.Wedge at 0x2377d5aca30>,
#   <matplotlib.patches.Wedge at 0x2377d5aceb0>,
#   <matplotlib.patches.Wedge at 0x2377d5ad330>,
#   <matplotlib.patches.Wedge at 0x2377d5ad7b0>,
#   <matplotlib.patches.Wedge at 0x2377d5adc30>,
#   <matplotlib.patches.Wedge at 0x2377d5ae0b0>,
#   <matplotlib.patches.Wedge at 0x2377d5ae560>,
#   <matplotlib.patches.Wedge at 0x2377d5ae9e0>,
#   <matplotlib.patches.Wedge at 0x2377d5aee60>,
#   <matplotlib.patches.Wedge at 0x2377d5af2e0>,
#   <matplotlib.patches.Wedge at 0x2377d5af760>,
#   <matplotlib.patches.Wedge at 0x2377d5afbe0>,
#   <matplotlib.patches.Wedge at 0x2377d5ec0a0>],
#  [Text(1.0761954575342128, 0.22760346478629606, '58'),
#   Text(0.9130918727354113, 0.6134029931004084, '57'),
#   Text(0.6587759965150654, 0.880916673934364, '54'),
#   Text(0.3654656195680134, 1.0375137979389808, '59'),
#   Text(0.07243410089677733, 1.0976125459501982, '52'),
#   Text(-0.20280669636252513, 1.0811426565955664, '51'),
#   Text(-0.45304982640055497, 1.0023701186679634, '56'),
#   Text(-0.6721979681370708, 0.8707180322196123, '62'),
#   Text(-0.8507791527637931, 0.6972623847752885, '60'),
#   Text(-0.9842814798469356, 0.49111095327871357, '44'),
#   Text(-1.0662749089340477, 0.2702920986223765, '64'),
#   Text(-1.0988376908266555, 0.05055422058289124, '41'),
#   Text(-1.0876180191169165, -0.16458142207489584, '63'),
#   Text(-1.0358226623694209, -0.3702315655396296, '67'),
#   Text(-0.9472450380233398, -0.5592198475914117, '61'),
#   Text(-0.8267922316809614, -0.7255443512508492, '55'),
#   Text(-0.6880958252650708, -0.858209843367449, '65'),
#   Text(-0.5402389471580247, -0.958197203071262, '43'),
#   Text(-0.3813218455576926, -1.0317914760747326, '42'),
#   Text(-0.2127390979683102, -1.0792321697371838, '53'),
#   Text(-0.04213308267562354, -1.0991927962574397, '66'),
#   Text(0.12615168652699404, -1.092742308134171, '45'),
#   Text(0.2849722372138717, -1.0624456805019826, '48'),
#   Text(0.4314415233620876, -1.011858790503399, '46'),
#   Text(0.5635688047076524, -0.9446640685240378, '50'),
#   Text(0.6721979120903466, -0.8707180754879152, '47'),
#   Text(0.7615601716503135, -0.7937418377255574, '49'),
#   Text(0.8356248413875912, -0.7153538456288352, '35'),
#   Text(0.8958260194979932, -0.6383539322275544, '39'),
#   Text(0.9472449496693027, -0.5592199972515293, '70'),
#   Text(0.9887554969454884, -0.48204000587096557, '68'),
#   Text(1.0215081726425415, -0.40806991217743066, '38'),
#   Text(1.04771383297041, -0.33510554188561514, '71'),
#   Text(1.0679117242244813, -0.2637509227735433, '40'),
#   Text(1.0820635947784987, -0.19783421558222272, '69'),
#   Text(1.0900123711777872, -0.14789533690883624, '37'),
#   Text(1.0947135105113268, -0.10771411190724879, '34'),
#   Text(1.0975002487726198, -0.07411615170823282, '29'),
#   Text(1.098837688312127, -0.050554275238215436, '76'),
#   Text(1.099581519411941, -0.03033944903467569, '77'),
#   Text(1.0999534988651865, -0.010114362769575846, '74')])

# %%
# c. Box Plots

plt.figure(figsize=(10,4))
sns.boxplot(df,x='chol')
plt.title('Cholesterol')
plt.xlabel('Cholesterol')
# Out:
# Text(0.5, 0, 'Cholesterol')

# %%
# d. Scatter plots

plt.figure(figsize=(10,4))
plt.scatter(df['age'],df['chol'],color='purple')
plt.title('Age vs Cholesterol')
plt.xlabel('Age')
plt.ylabel('Cholesterol')
# Out:
# Text(0, 0.5, 'Cholesterol')

# %%
# e. Add boxplots to a scatterplot 

plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
sns.boxplot(df,x='age')

plt.subplot(1,2,2)
plt.scatter(df['age'],df['chol'],color='purple')
